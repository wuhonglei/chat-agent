# %%
from tavily import TavilyClient

tavily_client = TavilyClient(
    api_key="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")
response = tavily_client.search(
    "2025年最新的AI发展趋势?", include_answer=False, search_depth="basic",)

response
# Out:
# {'query': '2025年最新的AI发展趋势?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.microsoft.com/en-us/research/articles/6-ai-trends-in-2025/',
#    'title': '2025年六大AI趋势展望- Microsoft Research',
# ...
